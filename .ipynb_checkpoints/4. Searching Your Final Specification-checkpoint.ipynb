# %% [markdown]
# ## Forward Pass

# %%
import os
import pandas as pd
import biogeme.database as db
import biogeme.biogeme as bio
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()

def estimateLogit(util, av, choice, modelName, database):
    """
    A function to avoid duplicated files when
    estimating Logit Models using Biogeme
    """
    folder, name = modelName.split('/')
    if (name + '.pickle') in os.listdir(folder):
        os.remove(modelName + '.pickle')
    if (name + '.html') in os.listdir(folder):
        os.remove(modelName + '.html')
    logprob = bioLogLogit(V,av,CHOSEN)
    biogeme  = bio.BIOGEME(database,logprob)
    biogeme.modelName = modelName
    return biogeme.estimate()

# %%
data = pd.read_csv('data/Data_HW_001.txt', sep='\t')
data['HIGH_INCOME'] = data['INCOME'].apply(lambda inc: int(inc == 3))
data['MEDIUM_INCOME'] = data['INCOME'].apply(lambda inc: int(inc == 2))
database = db.Database('Data_HW_001', data)
from headers import *

# %%
ASC_YES = Beta('ASC_YES', 0, None, None, 0)
ASC_NO = Beta('ASC_NO', 0, None, None, 1)
BETA_INCOME = Beta('BETA_INCOME', 0, None, None, 0)
BETA_HHSIZE = Beta('BETA_HHSIZE', 0, None, None, 0)
BETA_NUMVEH = Beta('BETA_NUMVEH', 0, None, None, 0)
BETA_WOMEN = Beta('BETA_WOMEN', 0, None, None, 0)
BETA_MEN = Beta('BETA_MEN', 0, None, None, 0)
BETA_NWORK = Beta('BETA_NWORK', 0, None, None, 0)
BETA_NCHILD = Beta('BETA_NCHILD', 0, None, None, 0)
BETA_NYCHILD = Beta('BETA_NYCHILD', 0, None, None, 0)
BETA_ETHN = Beta('BETA_ETHN', 0, None, None, 0)
BETA_DIST = Beta('BETA_DIST', 0, None, None, 0)
BETA_NBIKES = Beta('BETA_NBIKES', 0, None, None, 0)
BETA_PTRANSP = Beta('BETA_PTRANSP', 0, None, None, 0)
BETA_SOLARPAN = Beta('BETA_SOLARPAN', 0, None, None, 0)
BETA_WALKBIKE = Beta('BETA_WALKBIKE', 0, None, None, 0)
BETA_TELECO = Beta('BETA_TELECO', 0, None, None, 0)
BETA_PSENIORS = Beta('BETA_PSENIORS', 0, None, None, 0)
BETA_GRAD = Beta('BETA_GRAD', 0, None, None, 0)
BETA_POPDENSE = Beta('BETA_POPDENSE', 0, None, None, 0)
BETA_NEIGHB = Beta('BETA_NEIGHB', 0, None, None, 0)
BETA_SMARTPH = Beta('BETA_SMARTPH', 0, None, None, 0)
BETA_SPOOL = Beta('BETA_SPOOL', 0, None, None, 0)
BETA_CABLE = Beta('BETA_CABLE', 0, None, None, 0)
BETA_COST = Beta('BETA_COST', 0, None,None, 0)
BETA_HIGH_INC_COST = Beta('BETA_HIGH_INC_COST', 0, None, None, 0)
BETA_MEDIUM_INC_COST = Beta('BETA_HIGH_MEDIUM_COST', 0, None, None, 0)
YES = DefineVariable('YES', (HHID != 0), database)
NO = DefineVariable('NO', (HHID != 0), database)
av = {1: YES, 2: NO}

# %% [markdown]
# # Constant Model

# %%
V1 = ASC_YES
V2 = ASC_NO
V = {1: V1, 2: V2}

# %%
results = estimateLogit(V, av, CHOSEN, 'output/FinalSpec', database)
print('Constant model rho-square-bar: ', results.getGeneralStatistics()['Rho-square-bar for the init. model'][0])
# Out:
# Constant model rho-square-bar:  0.3651705552042527

# %% [markdown]
# ### Add Variable Income

# %%
V1 = ASC_YES + BETA_INCOME * INCOME
V2 = ASC_NO
V = {1: V1, 2: V2}

# %%
results = estimateLogit(V, av, CHOSEN, 'output/FinalSpec', database)
display(results.getEstimatedParameters())
print('Income model rho-square-bar: ', results.getGeneralStatistics()['Rho-square-bar for the init. model'][0])
# Out:
#                 Value   Std err     t-test   p-value  Rob. Std err  \
# ASC_YES     -2.014415  0.136086 -14.802481  0.000000      0.133411
# BETA_INCOME  0.196755  0.068073   2.890359  0.003848      0.066584
#
#              Rob. t-test  Rob. p-value
# ASC_YES       -15.099299      0.000000
# BETA_INCOME     2.954993      0.003127
# Income model rho-square-bar:  0.36680676956480185

# %% [markdown]
# INCOME stays in the model

# %% [markdown]
# ## HHSIZE or WOMEN & MEN

# %%
V1 = ASC_YES + BETA_INCOME * INCOME + BETA_HHSIZE * HHSIZE
V2 = ASC_NO
V = {1: V1, 2: V2}
results = estimateLogit(V, av, CHOSEN, 'output/FinalSpec', database)
display(results.getEstimatedParameters())
print('HHSIZE model rho-square-bar: ', results.getGeneralStatistics()['Rho-square-bar for the init. model'][0])
# Out:
#                 Value   Std err     t-test   p-value  Rob. Std err  \
# ASC_YES     -2.190207  0.162793 -13.453906  0.000000      0.159621
# BETA_HHSIZE  0.065138  0.032233   2.020832  0.043297      0.032205
# BETA_INCOME  0.199270  0.068176   2.922885  0.003468      0.066666
#
#              Rob. t-test  Rob. p-value
# ASC_YES       -13.721269      0.000000
# BETA_HHSIZE     2.022599      0.043115
# BETA_INCOME     2.989087      0.002798
# HHSIZE model rho-square-bar:  0.36732708480365295

# %%
V1 = ASC_YES + BETA_INCOME * INCOME + BETA_WOMEN * WOMEN + BETA_MEN * MEN
V2 = ASC_NO
V = {1: V1, 2: V2}
results = estimateLogit(V, av, CHOSEN, 'output/FinalSpec', database)
display(results.getEstimatedParameters())
print('WOMEN and MEN model rho-square-bar: ', results.getGeneralStatistics()['Rho-square-bar for the init. model'][0])
# Out:
#                 Value   Std err     t-test   p-value  Rob. Std err  \
# ASC_YES     -2.192783  0.163174 -13.438294  0.000000      0.160055
# BETA_INCOME  0.202715  0.068260   2.969731  0.002981      0.066693
# BETA_MEN     0.004734  0.043387   0.109111  0.913114      0.042564
# BETA_WOMEN   0.119000  0.040157   2.963380  0.003043      0.039930
#
#              Rob. t-test  Rob. p-value
# ASC_YES       -13.700184      0.000000
# BETA_INCOME     3.039518      0.002370
# BETA_MEN        0.111222      0.911440
# BETA_WOMEN      2.980204      0.002881
# WOMEN and MEN model rho-square-bar:  0.3680334043173179

# %%
V1 = ASC_YES + BETA_INCOME * INCOME + BETA_WOMEN * WOMEN
V2 = ASC_NO
V = {1: V1, 2: V2}
results = estimateLogit(V, av, CHOSEN, 'output/FinalSpec', database)
display(results.getEstimatedParameters())
print('WOMEN model rho-square-bar: ', results.getGeneralStatistics()['Rho-square-bar for the init. model'][0])
# Out:
#                 Value   Std err     t-test   p-value  Rob. Std err  \
# ASC_YES     -2.185526  0.149058 -14.662227  0.000000      0.144864
# BETA_INCOME  0.202681  0.068259   2.969307  0.002985      0.066691
# BETA_WOMEN   0.118128  0.039324   3.003959  0.002665      0.038875
#
#              Rob. t-test  Rob. p-value
# ASC_YES       -15.086739      0.000000
# BETA_INCOME     3.039094      0.002373
# BETA_WOMEN      3.038667      0.002376
# WOMEN model rho-square-bar:  0.3685502050761065

# %%
ALONE = DefineVariable('ALONE', (HHSIZE <= 1), database)
BETA_ALONE = Beta('BETA_ALONE', 0, None, None, 0)

# %%
V1 = ASC_YES + BETA_INCOME * INCOME + BETA_WOMEN * WOMEN + BETA_ALONE * ALONE
V2 = ASC_NO
V = {1: V1, 2: V2}
results = estimateLogit(V, av, CHOSEN, 'output/FinalSpec', database)
display(results.getEstimatedParameters())
print('ALONE model rho-square-bar: ', results.getGeneralStatistics()['Rho-square-bar for the init. model'][0])
# Out:
#                 Value   Std err     t-test   p-value  Rob. Std err  \
# ASC_YES     -2.135166  0.161271 -13.239651  0.000000      0.156822
# BETA_ALONE  -0.103393  0.128546  -0.804332  0.421205      0.127432
# BETA_INCOME  0.203119  0.068282   2.974712  0.002933      0.066716
# BETA_WOMEN   0.102733  0.043736   2.348902  0.018829      0.043023
#
#              Rob. t-test  Rob. p-value
# ASC_YES       -13.615246      0.000000
# BETA_ALONE     -0.811360      0.417159
# BETA_INCOME     3.044545      0.002330
# BETA_WOMEN      2.387878      0.016946
# ALONE model rho-square-bar:  0.36819938486889014

# %% [markdown]
# ### NUMVEH

# %%
V1 = ASC_YES + BETA_INCOME * INCOME + BETA_WOMEN * WOMEN + BETA_HHSIZE * HHSIZE
V2 = ASC_NO
V = {1: V1, 2: V2}
results = estimateLogit(V, av, CHOSEN, 'output/FinalSpec', database)
display(results.getEstimatedParameters())
print('HHSIZE model rho-square-bar: ', results.getGeneralStatistics()['Rho-square-bar for the init. model'][0])
# Out:
#                 Value   Std err     t-test   p-value  Rob. Std err  \
# ASC_YES     -2.192696  0.163173 -13.437848  0.000000      0.160053
# BETA_HHSIZE  0.004744  0.043387   0.109332  0.912939      0.042563
# BETA_INCOME  0.202664  0.068261   2.968984  0.002988      0.066693
# BETA_WOMEN   0.114254  0.052775   2.164899  0.030395      0.051143
#
#              Rob. t-test  Rob. p-value
# ASC_YES       -13.699815      0.000000
# BETA_HHSIZE     0.111448      0.911261
# BETA_INCOME     3.038749      0.002376
# BETA_WOMEN      2.233985      0.025484
# HHSIZE model rho-square-bar:  0.36803340419436004

# %% [markdown]
# ### NWORK

# %%
V1 = ASC_YES + BETA_INCOME * INCOME + BETA_WOMEN * WOMEN + BETA_NWORK * NWORK
V2 = ASC_NO
V = {1: V1, 2: V2}
results = estimateLogit(V, av, CHOSEN, 'output/FinalSpec', database)
display(results.getEstimatedParameters())
print('NWORK model rho-square-bar: ', results.getGeneralStatistics()['Rho-square-bar for the init. model'][0])
# Out:
#                 Value   Std err     t-test   p-value  Rob. Std err  \
# ASC_YES     -2.160493  0.169561 -12.741692  0.000000      0.161889
# BETA_INCOME  0.202495  0.068265   2.966292  0.003014      0.066683
# BETA_NWORK  -0.021670  0.070142  -0.308941  0.757366      0.069912
# BETA_WOMEN   0.122155  0.041412   2.949731  0.003181      0.042091
#
#              Rob. t-test  Rob. p-value
# ASC_YES       -13.345547      0.000000
# BETA_INCOME     3.036666      0.002392
# BETA_NWORK     -0.309958      0.756593
# BETA_WOMEN      2.902122      0.003706
# NWORK model rho-square-bar:  0.36805531595565477

# %% [markdown]
# ### NCHILD

# %%
V1 = ASC_YES + BETA_INCOME * INCOME + BETA_WOMEN * WOMEN + BETA_NCHILD * NCHILD
V2 = ASC_NO
V = {1: V1, 2: V2}
results = estimateLogit(V, av, CHOSEN, 'output/FinalSpec', database)
display(results.getEstimatedParameters())
print('NCHILD model rho-square-bar: ', results.getGeneralStatistics()['Rho-square-bar for the init. model'][0])
# Out:
#                 Value   Std err     t-test   p-value  Rob. Std err  \
# ASC_YES     -2.184633  0.149435 -14.619319  0.000000      0.145730
# BETA_INCOME  0.202635  0.068264   2.968405  0.002993      0.066691
# BETA_NCHILD -0.002855  0.049607  -0.057546  0.954110      0.047726
# BETA_WOMEN   0.119283  0.044643   2.671970  0.007541      0.041904
#
#              Rob. t-test  Rob. p-value
# ASC_YES       -14.990971      0.000000
# BETA_INCOME     3.038426      0.002378
# BETA_NCHILD    -0.059813      0.952305
# BETA_WOMEN      2.846569      0.004419
# NCHILD model rho-square-bar:  0.368031189242388

# %% [markdown]
# ### NYCHILD

# %%
V1 = ASC_YES + BETA_INCOME * INCOME + BETA_WOMEN * WOMEN + BETA_NYCHILD * NYCHILD
V2 = ASC_NO
V = {1: V1, 2: V2}
results = estimateLogit(V, av, CHOSEN, 'output/FinalSpec', database)
display(results.getEstimatedParameters())
print('NYCHILD model rho-square-bar: ', results.getGeneralStatistics()['Rho-square-bar for the init. model'][0])
# Out:
#                  Value   Std err     t-test   p-value  Rob. Std err  \
# ASC_YES      -2.188531  0.149255 -14.663068  0.000000      0.145118
# BETA_INCOME   0.203856  0.068291   2.985093  0.002835      0.066709
# BETA_NYCHILD -0.071031  0.098347  -0.722247  0.470143      0.093804
# BETA_WOMEN    0.127966  0.041569   3.078372  0.002081      0.040306
#
#               Rob. t-test  Rob. p-value
# ASC_YES        -15.081041      0.000000
# BETA_INCOME      3.055890      0.002244
# BETA_NYCHILD    -0.757226      0.448914
# BETA_WOMEN       3.174893      0.001499
# NYCHILD model rho-square-bar:  0.3681700791825995

# %% [markdown]
# ## ETHN

# %%
WHITE = DefineVariable('WHITE', (ETHN == 1), database)
AFRICAN = DefineVariable('AFRICAN', (ETHN == 2), database)
ASIAN = DefineVariable('ASIAN',(ETHN == 3), database)
BETA_WHITE = Beta('BETA_WHITE', 0, None, None, 0)
BETA_AFRICAN = Beta('BETA_AFRICAN', 0, None, None, 0)
BETA_ASIAN = Beta('BETA_ASIAN', 0, None, None, 0)

# %%
V1 = ASC_YES + BETA_INCOME * INCOME + BETA_WOMEN * WOMEN + BETA_WHITE * WHITE + BETA_AFRICAN * AFRICAN + BETA_ASIAN * ASIAN
V2 = ASC_NO
V = {1: V1, 2: V2}
results = estimateLogit(V, av, CHOSEN, 'output/FinalSpec', database)
display(results.getEstimatedParameters())
print('ETHN model rho-square-bar: ', results.getGeneralStatistics()['Rho-square-bar for the init. model'][0])
# Out:
#                  Value   Std err     t-test   p-value  Rob. Std err  \
# ASC_YES      -2.214183  0.162433 -13.631339  0.000000      0.160399
# BETA_AFRICAN  0.392849  0.193219   2.033181  0.042034      0.193151
# BETA_ASIAN    0.117410  0.162474   0.722636  0.469904      0.162677
# BETA_INCOME   0.202883  0.068345   2.968525  0.002992      0.066907
# BETA_WHITE   -0.059153  0.118369  -0.499729  0.617266      0.118483
# BETA_WOMEN    0.121083  0.039406   3.072709  0.002121      0.038898
#
#               Rob. t-test  Rob. p-value
# ASC_YES        -13.804208      0.000000
# BETA_AFRICAN     2.033897      0.041962
# BETA_ASIAN       0.721738      0.470456
# BETA_INCOME      3.032329      0.002427
# BETA_WHITE      -0.499252      0.617602
# BETA_WOMEN       3.112849      0.001853
# ETHN model rho-square-bar:  0.3684569192844618

# %%
V1 = ASC_YES + BETA_INCOME * INCOME + BETA_WOMEN * WOMEN + BETA_AFRICAN * AFRICAN
V2 = ASC_NO
V = {1: V1, 2: V2}
results = estimateLogit(V, av, CHOSEN, 'output/FinalSpec', database)
display(results.getEstimatedParameters())
print('AFRICAN model rho-square-bar: ', results.getGeneralStatistics()['Rho-square-bar for the init. model'][0])
# Out:
#                  Value   Std err     t-test   p-value  Rob. Std err  \
# ASC_YES      -2.218418  0.150181 -14.771627  0.000000      0.145977
# BETA_AFRICAN  0.400520  0.183129   2.187089  0.028736      0.183013
# BETA_INCOME   0.201524  0.068327   2.949401  0.003184      0.066834
# BETA_WOMEN    0.120414  0.039392   3.056785  0.002237      0.038822
#
#               Rob. t-test  Rob. p-value
# ASC_YES        -15.197080      0.000000
# BETA_AFRICAN     2.188481      0.028635
# BETA_INCOME      3.015287      0.002567
# BETA_WOMEN       3.101676      0.001924
# AFRICAN model rho-square-bar:  0.3691962519994274

# %% [markdown]
# AFRICAN stays in the model

# %% [markdown]
# ### DIST

# %%
SDIST = DefineVariable('SDIS', (DIST < 4), database)
BETA_SDIST = Beta('BETA_SDIST', 0, None, None, 0)
V1 = ASC_YES + BETA_INCOME * INCOME + BETA_WOMEN * WOMEN + BETA_AFRICAN * AFRICAN + BETA_SDIST * SDIST
V2 = ASC_NO
V = {1: V1, 2: V2}
results = estimateLogit(V, av, CHOSEN, 'output/FinalSpec', database)
display(results.getEstimatedParameters())
print('SDIST model rho-square-bar: ', results.getGeneralStatistics()['Rho-square-bar for the init. model'][0])
# Out:
#                  Value   Std err     t-test   p-value  Rob. Std err  \
# ASC_YES      -2.195182  0.197772 -11.099536  0.000000      0.186121
# BETA_AFRICAN  0.401494  0.183205   2.191498  0.028416      0.182979
# BETA_INCOME   0.201292  0.068342   2.945348  0.003226      0.066754
# BETA_SDIST   -0.026456  0.146629  -0.180430  0.856815      0.145143
# BETA_WOMEN    0.120189  0.039410   3.049673  0.002291      0.038762
#
#               Rob. t-test  Rob. p-value
# ASC_YES        -11.794356      0.000000
# BETA_AFRICAN     2.194205      0.028221
# BETA_INCOME      3.015427      0.002566
# BETA_SDIST      -0.182278      0.855365
# BETA_WOMEN       3.100721      0.001931
# SDIST model rho-square-bar:  0.36868479537752286

# %%
V1 = ASC_YES + BETA_INCOME * INCOME + BETA_WOMEN * WOMEN + BETA_AFRICAN * AFRICAN + BETA_DIST * DIST
V2 = ASC_NO
V = {1: V1, 2: V2}
results = estimateLogit(V, av, CHOSEN, 'output/FinalSpec', database)
display(results.getEstimatedParameters())
print('DIST model rho-square-bar: ', results.getGeneralStatistics()['Rho-square-bar for the init. model'][0])
# Out:
#                  Value   Std err     t-test   p-value  Rob. Std err  \
# ASC_YES      -2.204734  0.175415 -12.568670  0.000000      0.175923
# BETA_AFRICAN  0.399343  0.183307   2.178545  0.029365      0.182758
# BETA_DIST    -0.005496  0.036497  -0.150600  0.880291      0.036569
# BETA_INCOME   0.201698  0.068336   2.951558  0.003162      0.066772
# BETA_WOMEN    0.120555  0.039406   3.059306  0.002219      0.038827
#
#               Rob. t-test  Rob. p-value
# ASC_YES        -12.532386      0.000000
# BETA_AFRICAN     2.185093      0.028882
# BETA_DIST       -0.150301      0.880527
# BETA_INCOME      3.020681      0.002522
# BETA_WOMEN       3.104897      0.001903
# DIST model rho-square-bar:  0.3686822740061987

# %% [markdown]
# ### NBIKES

# %%
V1 = ASC_YES + BETA_INCOME * INCOME + BETA_WOMEN * WOMEN + BETA_AFRICAN * AFRICAN + BETA_NBIKES * NBIKES
V2 = ASC_NO
V = {1: V1, 2: V2}
results = estimateLogit(V, av, CHOSEN, 'output/FinalSpec', database)
display(results.getEstimatedParameters())
print('NBIKES model rho-square-bar: ', results.getGeneralStatistics()['Rho-square-bar for the init. model'][0])
# Out:
#                  Value   Std err     t-test   p-value  Rob. Std err  \
# ASC_YES      -2.218694  0.150167 -14.774890  0.000000      0.145965
# BETA_AFRICAN  0.396851  0.183272   2.165368  0.030360      0.182911
# BETA_INCOME   0.201954  0.068341   2.955112  0.003126      0.066826
# BETA_NBIKES   0.033440  0.063622   0.525594  0.599170      0.061208
# BETA_WOMEN    0.108554  0.045428   2.389589  0.016867      0.043932
#
#               Rob. t-test  Rob. p-value
# ASC_YES        -15.200172      0.000000
# BETA_AFRICAN     2.169642      0.030034
# BETA_INCOME      3.022098      0.002510
# BETA_NBIKES      0.546324      0.584843
# BETA_WOMEN       2.470962      0.013475
# NBIKES model rho-square-bar:  0.36874744668574433

# %% [markdown]
# ### PTRANSP

# %%
V1 = ASC_YES + BETA_INCOME * INCOME + BETA_WOMEN * WOMEN + BETA_AFRICAN * AFRICAN + BETA_PTRANSP * PTRANSP
V2 = ASC_NO
V = {1: V1, 2: V2}
results = estimateLogit(V, av, CHOSEN, 'output/FinalSpec', database)
display(results.getEstimatedParameters())
print('PTRANSP model rho-square: ', results.getGeneralStatistics()['Rho-square for the init. model'][0])
print('PTRANSP model rho-square-bar: ', results.getGeneralStatistics()['Rho-square-bar for the init. model'][0])
# Out:
#                  Value   Std err     t-test   p-value  Rob. Std err  \
# ASC_YES      -2.139703  0.152414 -14.038750  0.000000      0.148453
# BETA_AFRICAN  0.408161  0.183414   2.225359  0.026057      0.183165
# BETA_INCOME   0.201953  0.068444   2.950622  0.003171      0.067097
# BETA_PTRANSP -0.347881  0.126585  -2.748198  0.005992      0.126343
# BETA_WOMEN    0.122111  0.039422   3.097522  0.001951      0.038863
#
#               Rob. t-test  Rob. p-value
# ASC_YES        -14.413379      0.000000
# BETA_AFRICAN     2.228380      0.025855
# BETA_INCOME      3.009876      0.002614
# BETA_PTRANSP    -2.753455      0.005897
# BETA_WOMEN       3.142082      0.001678
# PTRANSP model rho-square:  0.37333189573024994
# PTRANSP model rho-square-bar:  0.3707324452061257

# %% [markdown]
# PTRANSP stays in the model.

# %% [markdown]
# ### SOLARPAN

# %%
V1 = ASC_YES + BETA_INCOME * INCOME + BETA_WOMEN * WOMEN + BETA_AFRICAN * AFRICAN + BETA_PTRANSP * PTRANSP + BETA_SOLARPAN * SOLARPAN
V2 = ASC_NO
V = {1: V1, 2: V2}
results = estimateLogit(V, av, CHOSEN, 'output/FinalSpec', database)
display(results.getEstimatedParameters())
print('SOLARPAN model rho-square: ', results.getGeneralStatistics()['Rho-square for the init. model'][0])
print('SOLARPAN model rho-square-bar: ', results.getGeneralStatistics()['Rho-square-bar for the init. model'][0])
# Out:
#                   Value   Std err     t-test   p-value  Rob. Std err  \
# ASC_YES       -2.117858  0.152957 -13.846119  0.000000      0.149190
# BETA_AFRICAN   0.402705  0.183532   2.194191  0.028222      0.183302
# BETA_INCOME    0.202025  0.068454   2.951229  0.003165      0.067041
# BETA_PTRANSP  -0.341927  0.126681  -2.699120  0.006952      0.126520
# BETA_SOLARPAN -0.307223  0.213267  -1.440555  0.149711      0.212749
# BETA_WOMEN     0.121387  0.039449   3.077065  0.002090      0.038850
#
#                Rob. t-test  Rob. p-value
# ASC_YES         -14.195727      0.000000
# BETA_AFRICAN      2.196951      0.028024
# BETA_INCOME       3.013440      0.002583
# BETA_PTRANSP     -2.702562      0.006881
# BETA_SOLARPAN    -1.444061      0.148722
# BETA_WOMEN        3.124469      0.001781
# SOLARPAN model rho-square:  0.37390796582332686
# SOLARPAN model rho-square-bar:  0.37078862519437783

# %% [markdown]
# ### WALKBIKE

# %%
V1 = ASC_YES + BETA_INCOME * INCOME + BETA_WOMEN * WOMEN + BETA_AFRICAN * AFRICAN + BETA_PTRANSP * PTRANSP +\
     BETA_WALKBIKE * WALKBIKE
V2 = ASC_NO
V = {1: V1, 2: V2}
results = estimateLogit(V, av, CHOSEN, 'output/FinalSpec', database)
display(results.getEstimatedParameters())
print('WALKBIKE model rho-square: ', results.getGeneralStatistics()['Rho-square for the init. model'][0])
print('WALKBIKE model rho-square-bar: ', results.getGeneralStatistics()['Rho-square-bar for the init. model'][0])
# Out:
#                   Value   Std err     t-test   p-value  Rob. Std err  \
# ASC_YES       -2.179207  0.156485 -13.926018  0.000000      0.152649
# BETA_AFRICAN   0.412518  0.183511   2.247919  0.024581      0.183325
# BETA_INCOME    0.200803  0.068446   2.933736  0.003349      0.067030
# BETA_PTRANSP  -0.352651  0.126697  -2.783413  0.005379      0.126776
# BETA_WALKBIKE  0.129502  0.111975   1.156529  0.247465      0.111884
# BETA_WOMEN     0.123686  0.039449   3.135359  0.001716      0.038802
#
#                Rob. t-test  Rob. p-value
# ASC_YES         -14.275900      0.000000
# BETA_AFRICAN      2.250200      0.024436
# BETA_INCOME       2.995728      0.002738
# BETA_PTRANSP     -2.781689      0.005408
# BETA_WALKBIKE     1.157469      0.247081
# BETA_WOMEN        3.187576      0.001435
# WALKBIKE model rho-square:  0.373676340998892
# WALKBIKE model rho-square-bar:  0.3705570003699429

# %% [markdown]
# ### TELECO

# %%
V1 = ASC_YES + BETA_INCOME * INCOME + BETA_WOMEN * WOMEN + BETA_AFRICAN * AFRICAN + BETA_PTRANSP * PTRANSP +\
     BETA_TELECO * TELECO
V2 = ASC_NO
V = {1: V1, 2: V2}
results = estimateLogit(V, av, CHOSEN, 'output/FinalSpec', database)
display(results.getEstimatedParameters())
print('TELECO model rho-square: ', results.getGeneralStatistics()['Rho-square for the init. model'][0])
print('TELECO model rho-square-bar: ', results.getGeneralStatistics()['Rho-square-bar for the init. model'][0])
# Out:
#                  Value   Std err     t-test   p-value  Rob. Std err  \
# ASC_YES      -2.147406  0.154649 -13.885693  0.000000      0.150215
# BETA_AFRICAN  0.405463  0.183640   2.207920  0.027250      0.183793
# BETA_INCOME   0.202226  0.068456   2.954113  0.003136      0.067119
# BETA_PTRANSP -0.348246  0.126594  -2.750891  0.005943      0.126347
# BETA_TELECO   0.038411  0.130030   0.295403  0.767686      0.130711
# BETA_WOMEN    0.122012  0.039423   3.094971  0.001968      0.038872
#
#               Rob. t-test  Rob. p-value
# ASC_YES        -14.295554      0.000000
# BETA_AFRICAN     2.206089      0.027378
# BETA_INCOME      3.012949      0.002587
# BETA_PTRANSP    -2.756275      0.005846
# BETA_TELECO      0.293863      0.768863
# BETA_WOMEN       3.138837      0.001696
# TELECO model rho-square:  0.3733543855261712
# TELECO model rho-square-bar:  0.37023504489722203

# %% [markdown]
# ### PSENIORS

# %%
V1 = ASC_YES + BETA_INCOME * INCOME + BETA_WOMEN * WOMEN + BETA_AFRICAN * AFRICAN + BETA_PTRANSP * PTRANSP +\
     BETA_PSENIORS * PSENIORS
V2 = ASC_NO
V = {1: V1, 2: V2}
results = estimateLogit(V, av, CHOSEN, 'output/FinalSpec', database)
display(results.getEstimatedParameters())
print('PSENIORS model rho-square: ', results.getGeneralStatistics()['Rho-square for the init. model'][0])
print('PSENIORS model rho-square-bar: ', results.getGeneralStatistics()['Rho-square-bar for the init. model'][0])
# Out:
#                   Value   Std err     t-test   p-value  Rob. Std err  \
# ASC_YES       -2.154359  0.153045 -14.076639  0.000000      0.149274
# BETA_AFRICAN   0.408803  0.183447   2.228448  0.025851      0.183287
# BETA_INCOME    0.203106  0.068457   2.966905  0.003008      0.067135
# BETA_PSENIORS  0.161593  0.138830   1.163965  0.244438      0.137811
# BETA_PTRANSP  -0.349151  0.126609  -2.757716  0.005821      0.126553
# BETA_WOMEN     0.111103  0.040620   2.735204  0.006234      0.039886
#
#                Rob. t-test  Rob. p-value
# ASC_YES         -14.432277      0.000000
# BETA_AFRICAN      2.230404      0.025721
# BETA_INCOME       3.025331      0.002484
# BETA_PSENIORS     1.172568      0.240969
# BETA_PTRANSP     -2.758926      0.005799
# BETA_WOMEN        2.785517      0.005344
# PSENIORS model rho-square:  0.37367714005972963
# PSENIORS model rho-square-bar:  0.3705577994307805

# %% [markdown]
# ### POPDENSE

# %%
V1 = ASC_YES + BETA_INCOME * INCOME + BETA_WOMEN * WOMEN + BETA_AFRICAN * AFRICAN + BETA_PTRANSP * PTRANSP +\
     BETA_POPDENSE * POPDENSE
V2 = ASC_NO
V = {1: V1, 2: V2}
results = estimateLogit(V, av, CHOSEN, 'output/FinalSpec', database)
display(results.getEstimatedParameters())
print('POPDENSE model rho-square: ', results.getGeneralStatistics()['Rho-square for the init. model'][0])
print('POPDENSE model rho-square-bar: ', results.getGeneralStatistics()['Rho-square-bar for the init. model'][0])
# Out:
#                   Value   Std err     t-test   p-value  Rob. Std err  \
# ASC_YES       -2.067789  0.156298 -13.229818  0.000000      0.151252
# BETA_AFRICAN   0.412419  0.183575   2.246592  0.024666      0.184215
# BETA_INCOME    0.200647  0.068550   2.927001  0.003422      0.067146
# BETA_POPDENSE -0.000011  0.000006  -2.011926  0.044228      0.000006
# BETA_PTRANSP  -0.341994  0.126698  -2.699291  0.006949      0.126448
# BETA_WOMEN     0.121899  0.039375   3.095888  0.001962      0.038673
#
#                Rob. t-test  Rob. p-value
# ASC_YES         -13.671140      0.000000
# BETA_AFRICAN      2.238796      0.025169
# BETA_INCOME       2.988210      0.002806
# BETA_POPDENSE    -2.028141      0.042546
# BETA_PTRANSP     -2.704629      0.006838
# BETA_WOMEN        3.152011      0.001622
# POPDENSE model rho-square:  0.3744259295250836
# POPDENSE model rho-square-bar:  0.37130658889613455

# %% [markdown]
# ### GRAD

# %%
V1 = ASC_YES + BETA_INCOME * INCOME + BETA_WOMEN * WOMEN + BETA_AFRICAN * AFRICAN + BETA_PTRANSP * PTRANSP +\
     BETA_POPDENSE * POPDENSE + BETA_GRAD * GRAD
V2 = ASC_NO
V = {1: V1, 2: V2}
results = estimateLogit(V, av, CHOSEN, 'output/FinalSpec', database)
display(results.getEstimatedParameters())
print('GRAD model rho-square: ', results.getGeneralStatistics()['Rho-square for the init. model'][0])
print('GRAD model rho-square-bar: ', results.getGeneralStatistics()['Rho-square-bar for the init. model'][0])
# Out:
#                   Value   Std err     t-test   p-value  Rob. Std err  \
# ASC_YES       -2.068232  0.156465 -13.218512  0.000000      0.151284
# BETA_AFRICAN   0.412344  0.183585   2.246064  0.024700      0.184060
# BETA_GRAD      0.006152  0.078448   0.078425  0.937490      0.074462
# BETA_INCOME    0.200609  0.068553   2.926349  0.003430      0.067132
# BETA_POPDENSE -0.000011  0.000006  -2.012655  0.044151      0.000006
# BETA_PTRANSP  -0.341814  0.126695  -2.697922  0.006977      0.126445
# BETA_WOMEN     0.121252  0.040159   3.019272  0.002534      0.039135
#
#                Rob. t-test  Rob. p-value
# ASC_YES         -13.671207      0.000000
# BETA_AFRICAN      2.240271      0.025073
# BETA_GRAD         0.082623      0.934151
# BETA_INCOME       2.988295      0.002805
# BETA_POPDENSE    -2.026638      0.042699
# BETA_PTRANSP     -2.703248      0.006867
# BETA_WOMEN        3.098280      0.001946
# GRAD model rho-square:  0.37442747346999206
# GRAD model rho-square-bar:  0.37078824273621813

# %% [markdown]
# ### NEIGHB

# %%
V1 = ASC_YES + BETA_INCOME * INCOME + BETA_WOMEN * WOMEN + BETA_AFRICAN * AFRICAN + BETA_PTRANSP * PTRANSP +\
     BETA_POPDENSE * POPDENSE + BETA_NEIGHB * NEIGHB
V2 = ASC_NO
V = {1: V1, 2: V2}
results = estimateLogit(V, av, CHOSEN, 'output/FinalSpec', database)
display(results.getEstimatedParameters())
print('NEIGHB model rho-square: ', results.getGeneralStatistics()['Rho-square for the init. model'][0])
print('NEIGHB model rho-square-bar: ', results.getGeneralStatistics()['Rho-square-bar for the init. model'][0])
# Out:
#                   Value   Std err     t-test   p-value  Rob. Std err  \
# ASC_YES       -2.168761  0.159367 -13.608579  0.000000      0.154512
# BETA_AFRICAN   0.448868  0.184392   2.434315  0.014920      0.185452
# BETA_INCOME    0.194655  0.068592   2.837888  0.004541      0.067008
# BETA_NEIGHB    0.434794  0.118266   3.676397  0.000237      0.117378
# BETA_POPDENSE -0.000011  0.000006  -1.970816  0.048745      0.000006
# BETA_PTRANSP  -0.331332  0.127003  -2.608858  0.009085      0.126979
# BETA_WOMEN     0.121796  0.039571   3.077874  0.002085      0.038814
#
#                Rob. t-test  Rob. p-value
# ASC_YES         -14.036157      0.000000
# BETA_AFRICAN      2.420399      0.015503
# BETA_INCOME       2.904966      0.003673
# BETA_NEIGHB       3.704234      0.000212
# BETA_POPDENSE    -1.983209      0.047344
# BETA_PTRANSP     -2.609350      0.009071
# BETA_WOMEN        3.137968      0.001701
# NEIGHB model rho-square:  0.37780115300441075
# NEIGHB model rho-square-bar:  0.3741619222706368

# %% [markdown]
# ### SMARTPH

# %%
V1 = ASC_YES + BETA_INCOME * INCOME + BETA_WOMEN * WOMEN + BETA_AFRICAN * AFRICAN + BETA_PTRANSP * PTRANSP +\
     BETA_POPDENSE * POPDENSE + BETA_NEIGHB * NEIGHB + BETA_SMARTPH * SMARTPH
V2 = ASC_NO
V = {1: V1, 2: V2}
results = estimateLogit(V, av, CHOSEN, 'output/FinalSpec', database)
display(results.getEstimatedParameters())
print('SMARTPH model rho-square: ', results.getGeneralStatistics()['Rho-square for the init. model'][0])
print('SMARTPH model rho-square-bar: ', results.getGeneralStatistics()['Rho-square-bar for the init. model'][0])
# Out:
#                   Value   Std err     t-test   p-value  Rob. Std err  \
# ASC_YES       -2.208759  0.160818 -13.734530  0.000000      0.156409
# BETA_AFRICAN   0.454843  0.184564   2.464418  0.013724      0.185789
# BETA_INCOME    0.198251  0.068694   2.886001  0.003902      0.067133
# BETA_NEIGHB    0.431399  0.118402   3.643523  0.000269      0.117618
# BETA_POPDENSE -0.000011  0.000006  -1.969062  0.048946      0.000006
# BETA_PTRANSP  -0.331951  0.127093  -2.611879  0.009005      0.127003
# BETA_SMARTPH   0.120814  0.053245   2.269025  0.023267      0.051392
# BETA_WOMEN     0.081601  0.043584   1.872265  0.061170      0.041511
#
#                Rob. t-test  Rob. p-value
# ASC_YES         -14.121691      0.000000
# BETA_AFRICAN      2.448169      0.014358
# BETA_INCOME       2.953133      0.003146
# BETA_NEIGHB       3.667790      0.000245
# BETA_POPDENSE    -1.979335      0.047778
# BETA_PTRANSP     -2.613724      0.008956
# BETA_SMARTPH      2.350827      0.018732
# BETA_WOMEN        1.965770      0.049325
# SMARTPH model rho-square:  0.37910336394290634
# SMARTPH model rho-square-bar:  0.3749442431043075

# %% [markdown]
# ### SPOOL

# %%
V1 = ASC_YES + BETA_INCOME * INCOME + BETA_WOMEN * WOMEN + BETA_AFRICAN * AFRICAN + BETA_PTRANSP * PTRANSP +\
     BETA_POPDENSE * POPDENSE + BETA_NEIGHB * NEIGHB + BETA_SMARTPH * SMARTPH + BETA_SPOOL * SPOOL
V2 = ASC_NO
V = {1: V1, 2: V2}
results = estimateLogit(V, av, CHOSEN, 'output/FinalSpec', database)
display(results.getEstimatedParameters())
print('SPOOL model rho-square: ', results.getGeneralStatistics()['Rho-square for the init. model'][0])
print('SPOOL model rho-square-bar: ', results.getGeneralStatistics()['Rho-square-bar for the init. model'][0])
# Out:
#                   Value   Std err     t-test   p-value  Rob. Std err  \
# ASC_YES       -2.238933  0.162354 -13.790474  0.000000      0.158378
# BETA_AFRICAN   0.457599  0.184720   2.477258  0.013240      0.185586
# BETA_INCOME    0.237724  0.074424   3.194193  0.001402      0.072930
# BETA_NEIGHB    0.431973  0.118468   3.646334  0.000266      0.117699
# BETA_POPDENSE -0.000011  0.000006  -1.962138  0.049746      0.000006
# BETA_PTRANSP  -0.326785  0.127124  -2.570604  0.010152      0.126976
# BETA_SMARTPH   0.122961  0.053303   2.306809  0.021065      0.051433
# BETA_SPOOL    -0.175965  0.129644  -1.357294  0.174688      0.130625
# BETA_WOMEN     0.081877  0.043568   1.879319  0.060201      0.041411
#
#                Rob. t-test  Rob. p-value
# ASC_YES         -14.136635      0.000000
# BETA_AFRICAN      2.465692      0.013675
# BETA_INCOME       3.259615      0.001116
# BETA_NEIGHB       3.670143      0.000242
# BETA_POPDENSE    -1.973902      0.048393
# BETA_PTRANSP     -2.573601      0.010065
# BETA_SMARTPH      2.390697      0.016816
# BETA_SPOOL       -1.347108      0.177946
# BETA_WOMEN        1.977181      0.048021
# SPOOL model rho-square:  0.3795886319570022
# SPOOL model rho-square-bar:  0.3749096210135786

# %% [markdown]
# ### CABLE

# %%
V1 = ASC_YES + BETA_INCOME * INCOME + BETA_WOMEN * WOMEN + BETA_AFRICAN * AFRICAN + BETA_PTRANSP * PTRANSP +\
     BETA_POPDENSE * POPDENSE + BETA_NEIGHB * NEIGHB + BETA_SMARTPH * SMARTPH + BETA_SPOOL * SPOOL + BETA_CABLE * CABLE
V2 = ASC_NO
V = {1: V1, 2: V2}
results = estimateLogit(V, av, CHOSEN, 'output/FinalSpec', database)
display(results.getEstimatedParameters())
print('CABLE model rho-square: ', results.getGeneralStatistics()['Rho-square for the init. model'][0])
print('CABLE model rho-square-bar: ', results.getGeneralStatistics()['Rho-square-bar for the init. model'][0])
# Out:
#                   Value   Std err     t-test   p-value  Rob. Std err  \
# ASC_YES       -2.215905  0.162972 -13.596838  0.000000      0.159104
# BETA_AFRICAN   0.452176  0.185010   2.444059  0.014523      0.185638
# BETA_CABLE     0.209283  0.118596   1.764675  0.077618      0.119818
# BETA_INCOME    0.174607  0.082740   2.110319  0.034831      0.081296
# BETA_NEIGHB    0.436077  0.118555   3.678270  0.000235      0.117820
# BETA_POPDENSE -0.000011  0.000006  -1.999427  0.045562      0.000006
# BETA_PTRANSP  -0.329748  0.127225  -2.591857  0.009546      0.127114
# BETA_SMARTPH   0.124439  0.053312   2.334141  0.019588      0.051370
# BETA_SPOOL    -0.176673  0.129709  -1.362075  0.173174      0.130733
# BETA_WOMEN     0.081957  0.043573   1.880916  0.059983      0.041328
#
#                Rob. t-test  Rob. p-value
# ASC_YES         -13.927393      0.000000
# BETA_AFRICAN      2.435785      0.014859
# BETA_CABLE        1.746666      0.080695
# BETA_INCOME       2.147797      0.031730
# BETA_NEIGHB       3.701204      0.000215
# BETA_POPDENSE    -2.008402      0.044601
# BETA_PTRANSP     -2.594112      0.009484
# BETA_SMARTPH      2.422396      0.015419
# BETA_SPOOL       -1.351409      0.176564
# BETA_WOMEN        1.983095      0.047357
# CABLE model rho-square:  0.38038923563024996
# CABLE model rho-square-bar:  0.37519033458200146

# %% [markdown]
# ### COST

# %%
sns.distplot(data['COST'])

# %%
V1 = ASC_YES + BETA_INCOME * INCOME + BETA_WOMEN * WOMEN + BETA_AFRICAN * AFRICAN + BETA_PTRANSP * PTRANSP +\
     BETA_POPDENSE * POPDENSE + BETA_NEIGHB * NEIGHB + BETA_SMARTPH * SMARTPH + BETA_SPOOL * SPOOL + BETA_CABLE * CABLE +\
     BETA_COST * COST
V2 = ASC_NO
V = {1: V1, 2: V2}
results = estimateLogit(V, av, CHOSEN, 'output/FinalSpec', database)
display(results.getEstimatedParameters())
print('COST model rho-square: ', results.getGeneralStatistics()['Rho-square for the init. model'][0])
print('COST model rho-square-bar: ', results.getGeneralStatistics()['Rho-square-bar for the init. model'][0])
# Out:
#                   Value   Std err    t-test   p-value  Rob. Std err  \
# ASC_YES       -1.929148  0.224980 -8.574770  0.000000      0.225098
# BETA_AFRICAN   0.457188  0.184629  2.476251  0.013277      0.184256
# BETA_CABLE     0.215561  0.118703  1.815959  0.069377      0.119947
# BETA_COST     -0.326910  0.179641 -1.819799  0.068790      0.181400
# BETA_INCOME    0.175145  0.082824  2.114648  0.034460      0.081382
# BETA_NEIGHB    0.442279  0.118687  3.726423  0.000194      0.117998
# BETA_POPDENSE -0.000011  0.000006 -1.991132  0.046466      0.000006
# BETA_PTRANSP  -0.330009  0.127296 -2.592461  0.009529      0.127190
# BETA_SMARTPH   0.124164  0.053382  2.325943  0.020022      0.051467
# BETA_SPOOL    -0.179402  0.129772 -1.382435  0.166838      0.130691
# BETA_WOMEN     0.084126  0.043652  1.927186  0.053956      0.041448
#
#                Rob. t-test  Rob. p-value
# ASC_YES          -8.570261      0.000000
# BETA_AFRICAN      2.481261      0.013092
# BETA_CABLE        1.797129      0.072315
# BETA_COST        -1.802151      0.071522
# BETA_INCOME       2.152127      0.031387
# BETA_NEIGHB       3.748206      0.000178
# BETA_POPDENSE    -1.998582      0.045654
# BETA_PTRANSP     -2.594603      0.009470
# BETA_SMARTPH      2.412481      0.015844
# BETA_SPOOL       -1.372722      0.169839
# BETA_WOMEN        2.029648      0.042392
# COST model rho-square:  0.38125841898955926
# COST model rho-square-bar:  0.37553962783648587

# %% [markdown]
# ### INCOME CATEGORICAL

# %%
BETA_HINCOME = Beta('BETA_HINCOME', 0, None, None, 0)
BETA_MINCOME = Beta('BETA_MINCOME', 0, None, None, 0)

# %%
V1 = ASC_YES + BETA_HINCOME * HIGH_INCOME + BETA_MINCOME * MEDIUM_INCOME + BETA_WOMEN * WOMEN + BETA_AFRICAN * AFRICAN + BETA_PTRANSP * PTRANSP +\
     BETA_POPDENSE * POPDENSE + BETA_NEIGHB * NEIGHB + BETA_SMARTPH * SMARTPH + BETA_SPOOL * SPOOL + BETA_CABLE * CABLE +\
     BETA_COST * COST
V2 = ASC_NO
V = {1: V1, 2: V2}
results = estimateLogit(V, av, CHOSEN, 'output/FinalSpec', database)
display(results.getEstimatedParameters())
print('INCOME CATEGORICAL model rho-square: ', results.getGeneralStatistics()['Rho-square for the init. model'][0])
print('INCOME CATEGORICAL model rho-square-bar: ', results.getGeneralStatistics()['Rho-square-bar for the init. model'][0])
# Out:
#                   Value   Std err    t-test   p-value  Rob. Std err  \
# ASC_YES       -1.813238  0.199687 -9.080391  0.000000      0.200788
# BETA_AFRICAN   0.443915  0.185305  2.395595  0.016593      0.185053
# BETA_CABLE     0.207671  0.118158  1.757569  0.078821      0.118672
# BETA_COST     -0.321823  0.179708 -1.790808  0.073324      0.181485
# BETA_HINCOME   0.323293  0.169320  1.909365  0.056215      0.168463
# BETA_MINCOME   0.328394  0.128285  2.559884  0.010471      0.128436
# BETA_NEIGHB    0.450912  0.118893  3.792588  0.000149      0.118253
# BETA_POPDENSE -0.000011  0.000006 -1.957293  0.050313      0.000006
# BETA_PTRANSP  -0.327510  0.127316 -2.572413  0.010099      0.127299
# BETA_SMARTPH   0.124055  0.053332  2.326102  0.020013      0.051294
# BETA_SPOOL    -0.183940  0.129288 -1.422718  0.154818      0.129776
# BETA_WOMEN     0.084048  0.043612  1.927187  0.053956      0.041403
#
#                Rob. t-test  Rob. p-value
# ASC_YES          -9.030618      0.000000
# BETA_AFRICAN      2.398857      0.016446
# BETA_CABLE        1.749952      0.080127
# BETA_COST        -1.773274      0.076183
# BETA_HINCOME      1.919075      0.054975
# BETA_MINCOME      2.556861      0.010562
# BETA_NEIGHB       3.813100      0.000137
# BETA_POPDENSE    -1.963756      0.049558
# BETA_PTRANSP     -2.572763      0.010089
# BETA_SMARTPH      2.418526      0.015584
# BETA_SPOOL       -1.417367      0.156376
# BETA_WOMEN        2.029982      0.042358
# INCOME CATEGORICAL model rho-square:  0.3818756667792039
# INCOME CATEGORICAL model rho-square-bar:  0.37563698552130576

# %% [markdown]
# ## Has child

# %%
HCHILD = DefineVariable('HCHILD', (NCHILD >= 1), database)
BETA_HCHILD = Beta('BETA_HCHILD', 0, None, None, 0)

# %%
V1 = ASC_YES + BETA_HINCOME * HIGH_INCOME + BETA_MINCOME * MEDIUM_INCOME + BETA_WOMEN * WOMEN + BETA_AFRICAN * AFRICAN + BETA_PTRANSP * PTRANSP +\
     BETA_POPDENSE * POPDENSE + BETA_NEIGHB * NEIGHB + BETA_SMARTPH * SMARTPH + BETA_SPOOL * SPOOL + BETA_CABLE * CABLE +\
     BETA_COST * COST + BETA_HCHILD * HCHILD
V2 = ASC_NO
V = {1: V1, 2: V2}
results = estimateLogit(V, av, CHOSEN, 'output/FinalSpec', database)
display(results.getEstimatedParameters())
print('INCOME CATEGORICAL model rho-square: ', results.getGeneralStatistics()['Rho-square for the init. model'][0])
print('INCOME CATEGORICAL model rho-square-bar: ', results.getGeneralStatistics()['Rho-square-bar for the init. model'][0])
# Out:
#                   Value   Std err    t-test   p-value  Rob. Std err  \
# ASC_YES       -1.777640  0.201212 -8.834660  0.000000      0.202323
# BETA_AFRICAN   0.432827  0.185462  2.333780  0.019607      0.185500
# BETA_CABLE     0.211913  0.118176  1.793195  0.072942      0.118552
# BETA_COST     -0.322889  0.179821 -1.795611  0.072556      0.181582
# BETA_HCHILD   -0.147262  0.115248 -1.277783  0.201326      0.113764
# BETA_HINCOME   0.320979  0.169330  1.895582  0.058015      0.168714
# BETA_MINCOME   0.332882  0.128349  2.593579  0.009498      0.128523
# BETA_NEIGHB    0.456837  0.119007  3.838724  0.000124      0.118297
# BETA_POPDENSE -0.000011  0.000006 -1.949595  0.051224      0.000006
# BETA_PTRANSP  -0.329323  0.127341 -2.586155  0.009705      0.127398
# BETA_SMARTPH   0.139320  0.054687  2.547582  0.010847      0.052839
# BETA_SPOOL    -0.184623  0.129402 -1.426737  0.153656      0.130014
# BETA_WOMEN     0.097688  0.045023  2.169722  0.030028      0.042465
#
#                Rob. t-test  Rob. p-value
# ASC_YES          -8.786163      0.000000
# BETA_AFRICAN      2.333299      0.019632
# BETA_CABLE        1.787516      0.073854
# BETA_COST        -1.778194      0.075372
# BETA_HCHILD      -1.294460      0.195506
# BETA_HINCOME      1.902509      0.057105
# BETA_MINCOME      2.590062      0.009596
# BETA_NEIGHB       3.861764      0.000113
# BETA_POPDENSE    -1.954750      0.050613
# BETA_PTRANSP     -2.584986      0.009738
# BETA_SMARTPH      2.636688      0.008372
# BETA_SPOOL       -1.420022      0.155601
# BETA_WOMEN        2.300444      0.021423
# INCOME CATEGORICAL model rho-square:  0.38230005865144034
# INCOME CATEGORICAL model rho-square-bar:  0.3755414872887173

# %% [markdown]
# ### Interaction WALKBIKE - NBIKES

# %%
BETA_WBIKES_NBIKES = Beta('BETA_WBIKES_NBIKES', 0, None, None, 0)
V1 = ASC_YES + BETA_HINCOME * HIGH_INCOME + BETA_MINCOME * MEDIUM_INCOME + BETA_WOMEN * WOMEN + BETA_AFRICAN * AFRICAN + BETA_PTRANSP * PTRANSP +\
     BETA_POPDENSE * POPDENSE + BETA_NEIGHB * NEIGHB + BETA_SMARTPH * SMARTPH + BETA_CABLE * CABLE +\
     BETA_COST * COST + BETA_WBIKES_NBIKES * WALKBIKE * NBIKES
V2 = ASC_NO
V = {1: V1, 2: V2}
results = estimateLogit(V, av, CHOSEN, 'output/FinalSpec', database)
display(results.getEstimatedParameters())
print('WBIKES - NBIKES model rho-square: ', results.getGeneralStatistics()['Rho-square for the init. model'][0])
print('WBIKES - NBIKES model rho-square-bar: ', results.getGeneralStatistics()['Rho-square-bar for the init. model'][0])
# Out:
#                        Value   Std err    t-test   p-value  Rob. Std err  \
# ASC_YES            -1.886369  0.196878 -9.581428  0.000000      0.198546
# BETA_AFRICAN        0.438736  0.184987  2.371711  0.017706      0.184389
# BETA_CABLE          0.202222  0.118048  1.713047  0.086704      0.118641
# BETA_COST          -0.321080  0.179870 -1.785065  0.074251      0.182081
# BETA_HINCOME        0.246303  0.159330  1.545867  0.122137      0.160498
# BETA_MINCOME        0.291181  0.124849  2.332260  0.019687      0.124659
# BETA_NEIGHB         0.442765  0.118985  3.721189  0.000198      0.118129
# BETA_PTRANSP       -0.350027  0.127474 -2.745871  0.006035      0.127025
# BETA_SMARTPH        0.113272  0.053585  2.113867  0.034527      0.051787
# BETA_WBIKES_NBIKES  0.159080  0.090079  1.765994  0.077397      0.091110
# BETA_WOMEN          0.070423  0.044517  1.581915  0.113669      0.042639
#
#                     Rob. t-test  Rob. p-value
# ASC_YES               -9.500926      0.000000
# BETA_AFRICAN           2.379403      0.017341
# BETA_CABLE             1.704486      0.088290
# BETA_COST             -1.763388      0.077835
# BETA_HINCOME           1.534621      0.124877
# BETA_MINCOME           2.335820      0.019501
# BETA_NEIGHB            3.748154      0.000178
# BETA_PTRANSP          -2.755572      0.005859
# BETA_SMARTPH           2.187260      0.028724
# BETA_WBIKES_NBIKES     1.746023      0.080807
# BETA_WOMEN             1.651590      0.098618
# WBIKES - NBIKES model rho-square:  0.3810753161800262
# WBIKES - NBIKES model rho-square-bar:  0.37535652502695294

# %% [markdown]
# ## Interaction INCOME - COST

# %%
V1 = ASC_YES + BETA_WOMEN * WOMEN + BETA_AFRICAN * AFRICAN + BETA_PTRANSP * PTRANSP +\
     BETA_NEIGHB * NEIGHB + BETA_SMARTPH * SMARTPH + BETA_CABLE * CABLE +\
     BETA_COST * COST + BETA_WBIKES_NBIKES * WALKBIKE * NBIKES + BETA_MEDIUM_INC_COST * MEDIUM_INCOME * COST + BETA_HIGH_INC_COST * HIGH_INCOME * COST
V2 = ASC_NO
V = {1: V1, 2: V2}
results = estimateLogit(V, av, CHOSEN, 'output/FinalSpec', database)
display(results.getEstimatedParameters())
print('WBIKES - NBIKES model rho-square: ', results.getGeneralStatistics()['Rho-square for the init. model'][0])
print('WBIKES - NBIKES model rho-square-bar: ', results.getGeneralStatistics()['Rho-square-bar for the init. model'][0])
# Out:
#                           Value   Std err    t-test   p-value  Rob. Std err  \
# ASC_YES               -1.710169  0.189830 -9.008959  0.000000      0.191103
# BETA_AFRICAN           0.438595  0.185024  2.370468  0.017766      0.184575
# BETA_CABLE             0.196964  0.116749  1.687067  0.091590      0.117809
# BETA_COST             -0.523516  0.198676 -2.635023  0.008413      0.201059
# BETA_HIGH_INC_COST     0.293303  0.166855  1.757834  0.078776      0.169692
# BETA_HIGH_MEDIUM_COST  0.333421  0.133301  2.501269  0.012375      0.133318
# BETA_NEIGHB            0.441143  0.119053  3.705431  0.000211      0.118109
# BETA_PTRANSP          -0.352891  0.127480 -2.768212  0.005636      0.127094
# BETA_SMARTPH           0.114731  0.053628  2.139387  0.032404      0.051821
# BETA_WBIKES_NBIKES     0.156557  0.090189  1.735881  0.082585      0.091086
# BETA_WOMEN             0.070630  0.044549  1.585435  0.112867      0.042702
#
#                        Rob. t-test  Rob. p-value
# ASC_YES                  -8.948942      0.000000
# BETA_AFRICAN              2.376235      0.017490
# BETA_CABLE                1.671897      0.094545
# BETA_COST                -2.603791      0.009220
# BETA_HIGH_INC_COST        1.728439      0.083909
# BETA_HIGH_MEDIUM_COST     2.500953      0.012386
# BETA_NEIGHB               3.735049      0.000188
# BETA_PTRANSP             -2.776612      0.005493
# BETA_SMARTPH              2.213989      0.026830
# BETA_WBIKES_NBIKES        1.718787      0.085653
# BETA_WOMEN                1.654043      0.098119
# WBIKES - NBIKES model rho-square:  0.38133285650422066
# WBIKES - NBIKES model rho-square-bar:  0.3756140653511473

# %%
V1 = ASC_YES + BETA_HINCOME * HIGH_INCOME + BETA_MINCOME * MEDIUM_INCOME + BETA_WOMEN * WOMEN + BETA_AFRICAN * AFRICAN + BETA_PTRANSP * PTRANSP +\
     BETA_POPDENSE * POPDENSE + BETA_NEIGHB * NEIGHB + BETA_SMARTPH * SMARTPH + BETA_SPOOL * SPOOL + BETA_CABLE * CABLE +\
     BETA_COST * COST + BETA_WBIKES_NBIKES * WALKBIKE * NBIKES
